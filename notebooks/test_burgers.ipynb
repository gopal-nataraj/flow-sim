# %%
import mediapy as mp
import numpy as np
results = np.load('../results/inviscidBurgers1d.npz')
u = results['u']
t = results['t']
u2d = np.transpose(np.tile(u, (u.shape[0], 1, 1)), (2, 0, 1))
mp.show_video(u2d, fps=1.0/(t[1]-t[0]))
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="256" height="256" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
